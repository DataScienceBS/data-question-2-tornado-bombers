# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
# %matplotlib inline

# %%
codes_violations=pd.read_excel("data/Codes_List_Of_Violations.xlsx")

# %%
codes_violations
# Out:
#                                           VIOLATION_ID            ORG_ID  \
# 0                                                    1                 1
# 1                                                    2                 1
# 2                                                    4                 1
# 3                                                    5                 1
# 4                                                    6                 1
# 5                                                    7                 1
# 6                                                    8                 1
# 7                                                    9                 1
# 8                                                   10                 1
# 9                                                   11                 1
# 10                                                  12                 1
# 11                                                  13                 1
# ...

# %%
type(codes_violations)
# Out:
# pandas.core.frame.DataFrame

# %%
codes_violations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 15 columns):
# VIOLATION_ID      928 non-null object
# ORG_ID            789 non-null object
# VIOLATION_TYPE    788 non-null object
# VIOLATION_DESC    925 non-null object
# VIOLATION_TEXT    666 non-null object
# REMEDIAL_TEXT     345 non-null object
# TABLE_NAME        137 non-null datetime64[ns]
# EXPIRED_FLAG      651 non-null object
# DATE_EXPIRED      2 non-null object
# CREATED_BY        650 non-null float64
# DATE_CREATED      651 non-null object
# MODIFIED_BY       23 non-null object
# DATE_MODIFIED     22 non-null datetime64[ns]
# FEE_SETUP_ID      0 non-null float64
# Unnamed: 14       0 non-null float64
# dtypes: datetime64[ns](2), float64(3), object(10)
# memory usage: 109.5+ KB

# %%
import sqlalchemy as sa
import psycopg2
import sys

# %%
engine=sa.create_engine('postgresql://postgres:postgres@localhost:5432/nashville')

# %%
conn = engine.connect()
selectstmt=conn.execute("select * from property_standards_violations")

# %%
print(selectstmt)

# %%
#read_sql_query also works
select_pd=pd.read_sql("select * from property_standards_violations",conn)
select_pd['violations_noted'].replace('None','UNKNOWN') 
select_pd['violations_noted'].str.upper()
# Out:
# 0                                               HIGH WEEDS
# 1                                                     None
# 2                                               HIGH WEEDS
# 3                                                     None
# 4                        OPEN STORAGE, JUNK, TRASH, DEBRIS
# 5                        OPEN STORAGE, JUNK, TRASH, DEBRIS
# 6                                                     None
# 7                        OPEN STORAGE, JUNK, TRASH, DEBRIS
# 8                          EXTERIOR REPAIR,INTERIOR REPAIR
# 9          EXTERIOR OF BUILDINGS � DOORS,USE NOT PERMITTED
# 10       EXTERIOR PROP AREA � OPEN STORAGE - ALL,EXTERI...
# 11                                        PROHIBITED SIGNS
# 12                         MOBILE VENDING,PARKING ON GRASS
# 13                                                    None
# 14                         EXTERIOR PROP AREA � HIGH WEEDS
# 15                                                    None
# ...

# %%
print(select_pd)
# Out:
#        request_no   date_recv        prop_apn              prop_address  \
# 0      17-1156755  2017-05-04     05814005400            121  QUEENS LN
# 1      17-1165789  2017-08-24     08116056500          1007  11TH AVE N
# 2      17-1157131  2017-05-09     10703001600             715  ERMAC DR
# 3      17-1161502  2017-07-06     07116009000        903  BLUE RIDGE DR
# 4      17-1153921  2017-03-06     11813018100       3605B  MAYFLOWER PL
# 5      17-1156955  2017-05-08     12001009000         1202  VULTEE BLVD
# 6      17-1165799  2017-08-24     10409011200        3723  RICHLAND AVE
# 7      17-1154514  2017-03-20     11613007600             5971  POST RD
# 8      15-1114246  2015-02-11     08102009600           1713  NUBELL ST
# 9      17-1153010  2017-02-10     07103005200      2402  DICKERSON PIKE
# 10     17-1153720  2017-03-01     14812018200          4641  ARTELIA DR
# 11     17-1152787  2017-02-08     14604005100        4712  TROUSDALE DR
# ...

# %%
select_pd.describe()
# Out:
#         request_no   date_recv     prop_apn         prop_address       city  \
# count        51438       51438        51002                51059      50819
# unique       51406         784        30204                30499         16
# top     16-1149433  2017-07-27  04313042100  335  FOREST PARK RD  NASHVILLE
# freq             7         194           51                   50      35124
#
#         state    zip              prop_owner complaint_source  \
# count   50869  51014                   51438            51344
# unique      1     37                   27875               18
# top        TN  37013  OWNER INFO UNAVAILABLE            PHONE
# freq    50869   6498                    6653            18827
#
#         reported_problem status council_district last_activity_date  \
# count              50730  51438            50901              51073
# unique             22408      3               35                819
# ...

# %%
type(select_pd)
# Out:
# pandas.core.frame.DataFrame

# %%
type(selectstmt)
# Out:
# sqlalchemy.engine.result.ResultProxy

# %%
#create a table in notebook and pushing it into postgres
#data =pd.read_sql("SELECT * from Cars",conn)
#data.to_sql('data',engine)

# %%
#updating records in the backend
conn.execute("""Update Cars set name='Range Rover' where Name='Hummer'""")

# %%
df3=select_pd
q=df3['violations_noted'].str.split(',',expand=True).stack().str.strip().reset_index(level=1,drop=True)
temp=pd.concat([q],axis=1,keys='violations_noted')
df4=df3.drop(['violations_noted'],axis=1).join(temp).reset_index(drop=True)
df4
# Out:
#         request_no   date_recv        prop_apn           prop_address  \
# 0       17-1156755  2017-05-04     05814005400         121  QUEENS LN
# 1       17-1165789  2017-08-24     08116056500       1007  11TH AVE N
# 2       17-1157131  2017-05-09     10703001600          715  ERMAC DR
# 3       17-1161502  2017-07-06     07116009000     903  BLUE RIDGE DR
# 4       17-1153921  2017-03-06     11813018100    3605B  MAYFLOWER PL
# 5       17-1153921  2017-03-06     11813018100    3605B  MAYFLOWER PL
# 6       17-1153921  2017-03-06     11813018100    3605B  MAYFLOWER PL
# 7       17-1153921  2017-03-06     11813018100    3605B  MAYFLOWER PL
# 8       17-1156955  2017-05-08     12001009000      1202  VULTEE BLVD
# 9       17-1156955  2017-05-08     12001009000      1202  VULTEE BLVD
# 10      17-1156955  2017-05-08     12001009000      1202  VULTEE BLVD
# 11      17-1156955  2017-05-08     12001009000      1202  VULTEE BLVD
# ...

# %%
from collections import Counter
types=list(df4['v'])
new=[]
for i in types:
    i=str(i).split(' ')
    for j in i:
        if j == '/' or j=='-' or j == chr(65533) :
            continue
        j=j.strip(chr(65533))    
        new.append(j.lower())
new=Counter(new)
print(new.most_common())
# Out:
# [('nan', 15832), ('storage', 15086), ('open', 15024), ('exterior', 11681), ('debris', 10633), ('trash', 10545), ('junk', 10496), ('high', 9780), ('weeds', 9780), ('area', 8299), ('prop', 8285), ('parking', 7730), ('on', 6753), ('grass', 6508), ('vehicles', 5179), ('accumulation', 4172), ('unlic', 4171), ('inop', 4171), ('mtr', 4171), ('of', 3234), ('all', 2834), ('use', 2326), ('permitted', 2186), ('not', 2184), ('veh', 2062), ('repair', 1842), ('required', 1635), ('permit', 1520), ('bldgs', 1273), ('prohibited', 1216), ('in', 1207), ('vehicle', 1183), ('signs', 1146), ('the', 1088), ('inop/unlc', 1071), ('residential', 1045), ('buildings', 1021), ('id', 950), ('right', 874), ('way', 874), ('building', 855), ('interior', 843), ('address', 817), ('jtd', 808), ('structures', 781), ('and', 766), ('system', 632), ('accessory', 559), ('sign', 507), ('roofs', 499), ('', 493), ('wind', 486), ('walls', 483), ('general', 473), ('commercial', 457), ('fence', 429), ('treatment', 417), ('strp', 
# ...

# %%
codes_violations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 15 columns):
# VIOLATION_ID      928 non-null object
# ORG_ID            789 non-null object
# VIOLATION_TYPE    788 non-null object
# VIOLATION_DESC    925 non-null object
# VIOLATION_TEXT    666 non-null object
# REMEDIAL_TEXT     345 non-null object
# TABLE_NAME        137 non-null datetime64[ns]
# EXPIRED_FLAG      651 non-null object
# DATE_EXPIRED      2 non-null object
# CREATED_BY        650 non-null float64
# DATE_CREATED      651 non-null object
# MODIFIED_BY       23 non-null object
# DATE_MODIFIED     22 non-null datetime64[ns]
# FEE_SETUP_ID      0 non-null float64
# Unnamed: 14       0 non-null float64
# dtypes: datetime64[ns](2), float64(3), object(10)
# memory usage: 109.5+ KB

# %%
#del codes_violations['Unnamed: 14']

# %%
codes_2_5 = codes_violations[['VIOLATION_TYPE','REMEDIAL_TEXT']]

# %%
codes_2_5['REMEDIAL_TEXT'].replace(np.NaN,"UNKNOWN")
# Out:
# 0              CAAZ_BANNERS
# 1          CAAH_BG_MATOWNER
# 2           CAAH_BLDG_MAINT
# 3          CAAB_BLDG_PERMIT
# 4           CAAH_BLDG_SCOPE
# 5        CAAH_BOARDING_REQU
# 6      CAAH_BOARDING_VABLDG
# 7           CAMCL_SEW_CONCT
# 8            CAAZ_CERT_COMP
# 9             CAAH_CERT_OCC
# 10       CAAZ_CHICK_ANIMALS
# 11        CAAZ_CONSIGN_SALE
# 12         CAAZ_OVCROWDEDFM
# 13         CAAZ_OVCROWDEDGH
# 14                  UNKNOWN
# 15                        1
# 16         CAMCL_LIT_NOTICE
# 17         CAAE_ELECSYS_HAZ
# 18     CAAE_ELECSYS_HAZCERT
# 19        CAAE_ELECEA_RECPT
# 20             CAAE_ELEC_EQ
# 21        CAAE_ELECEQ_LIGHT
# 22             CAAE_ELECFAC
# 23       CAAE_ELECSVC_PANEL
# 24            CAAH_EXT_PARK
# 25             CAAH_EXT_ACC
# 26           CAAH_EXT_BAHAT
# 27           CAAH_EXT_BALCO
# 28          CAAH_EXT_CHIMTW
# 29            CAAH_EXT_DECK
#                ...
# 904                 UNKNOWN
# 905                   10635
# ...

# %%
c=codes_2_5.REMEDIAL_TEXT.value_counts()

# %%
'''categories = []
for index, row in codes_violations.iterrows():
    i = row['VIOLATION_ID']
    r = row['REMEDIAL_TEXT']
    vt = str(row['VIOLATION_TYPE'])
    try:
        i = int(i)
    except:
        continue
    
    if str(r) == 'nan' or str(r) != str(r).upper():
        categories.append(vt[:4])
        continue
    else:
        categories.append(r[:4])

cats = {}
categories = list(set(categories))
for item in categories:
    if item[:3] == 'CAA':
        cats[item] = item
    elif item[:2] == 'BB':
        cats['BB'] = item
    elif item[:2] == 'HD':
        cats['HD'] = item
    elif item[:2] == 'SW':
        cats['SW'] = item
    else:
        cats[item[:3]] = item

print(len(cats.keys())) '''
# Out:
# "categories = []\nfor index, row in codes_violations.iterrows():\n    i = row['VIOLATION_ID']\n    r = row['REMEDIAL_TEXT']\n    vt = str(row['VIOLATION_TYPE'])\n    try:\n        i = int(i)\n    except:\n        continue\n    \n    if str(r) == 'nan' or str(r) != str(r).upper():\n        categories.append(vt[:4])\n        continue\n    else:\n        categories.append(r[:4])\n\ncats = {}\ncategories = list(set(categories))\nfor item in categories:\n    if item[:3] == 'CAA':\n        cats[item] = item\n    elif item[:2] == 'BB':\n        cats['BB'] = item\n    elif item[:2] == 'HD':\n        cats['HD'] = item\n    elif item[:2] == 'SW':\n        cats['SW'] = item\n    else:\n        cats[item[:3]] = item\n\nprint(len(cats.keys())) "

# %%
categories = []

def set_category(dictionary, check, dataframe, index):
    for m, n in dictionary.items():
        for item in n:
            if item in check:
                dataframe.loc[index,'CATEGORY'] = m
        

                

def categorize(df, *args):
    test_scenario = len(args) == 1
    if test_scenario:
        l = args[0]
    for index, row in df.iterrows():
        i = row['VIOLATION_ID']
        v = str(row['VIOLATION_TYPE'])
        r = row['REMEDIAL_TEXT']
        try:
            int(i)
        except:
            continue
    
        if str(r) == 'nan' or str(r) != str(r).upper():
            if test_scenario:
                l.append(v[:4])
                continue
            else:
                set_category(cats, v, df, index)
                
        else:
            if test_scenario:
                l.append(r[:4])

                continue
            else:
                set_category(cats, r, df, index)
                
              
    if test_scenario:
        return l
    else:
        return df
    
categories = categorize(codes_violations, categories)

'''for index, row in codes.iterrows():
    i = row['VIOLATION_ID']
    r = row['REMEDIAL_TEXT']
    v = row['VIOLATION_TYPE']
    try:
        i = int(i)
    except:
        continue
    
    if str(r) == 'nan' or str(r) != str(r).upper():
        categories.append(v[:4])
        continue
    else:
        categories.append(r[:4])'''

categories = list(set(categories))
cats = {}

for cat in categories:
    if cat[:3] == 'CAA':
        cats[cat] = []
    elif cat[:2] == 'CA':
        cats[cat[:3]] = []
    elif cat[:3] == 'DUM':
        cats[cat[:3]] = []
    elif cat[0] == '9':
        cats[cat] = []
    else:
        cats[cat[:2]] = []

for i in categories:
    for j in cats.keys():
        if j in i:
            cats[j].append(i)
            break
    
print(cats)
print(len(cats.keys()))
c = []
for v in cats.values():
    for k in v:
        c.append(k)
print(len(c))

new_codes = categorize(codes_violations)
new_codes.to_csv('checker.csv')
# Out:
# {'CAAZ': ['CAAZ'], 'CAAM': ['CAAM'], 'CAE': ['CAE0', 'CAE1', 'CAE2'], 'CAG': ['CAGA', 'CAGB', 'CAGK', 'CAGD', 'CAGC', 'CAGR', 'CAGZ', 'CAGJ', 'CAGP', 'CAGG', 'CAGM', 'CAGT', 'CAGF', 'CAGO', 'CAGE', 'CAGU', 'CAGI', 'CAGL', 'CAGH', 'CAGX', 'CAGQ', 'CAGV'], 'CAP': ['CAP1', 'CAP5', 'CAP2', 'CAP0', 'CAP4', 'CAP3'], 'BB': ['BB72', 'BBR6', 'BBR4', 'BBR9', 'BB07', 'BBR2', 'BBR8', 'BB70', 'BBR1', 'BBR3'], 'CAAH': ['CAAH'], 'CAM': ['CAMC'], '917': ['917'], 'DUM': ['DUMP'], 'CAZ': ['CAZZ'], 'CAAR': ['CAAR'], 'CAS': ['CAST'], 'SW': ['SWEN', 'SWVI'], 'CAAF': ['CAAF'], 'BT': ['BT57', 'BT54'], 'HD': ['HD15', 'HD10', 'HDVI', 'HD16', 'HDPM'], 'CAAP': ['CAAP'], 'CAH': ['CAHC'], 'CAAE': ['CAAE'], 'CAAB': ['CAAB'], 'CAAA': ['CAAA'], 'CAL': ['CALL']}
# 23
# 66

# %%
#vio_with_cats = pd.merge(cleaning_standards, cleaning_prop.iloc[17:], how='left', left_on='violations_noted', right_on='VIOLATION_DESC', left_index=False, right_index=False)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104320 entries, 0 to 104319
# Data columns (total 17 columns):
# request_no            104320 non-null object
# date_recv             104320 non-null object
# prop_apn              103706 non-null object
# prop_address          103796 non-null object
# city                  103399 non-null object
# state                 103474 non-null object
# zip                   103731 non-null object
# prop_owner            104320 non-null object
# complaint_source      104078 non-null object
# reported_problem      102991 non-null object
# status                104320 non-null object
# council_district      103551 non-null object
# last_activity_date    103949 non-null object
# last_activity         103949 non-null object
# last_activity_code    103921 non-null object
# mapped_loc            103798 non-null object
# v                     88488 non-null object
# dtypes: object(17)
# memory usage: 13.5+ MB

# %%
select_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51438 entries, 0 to 51437
# Data columns (total 17 columns):
# request_no            51438 non-null object
# date_recv             51438 non-null object
# prop_apn              51002 non-null object
# prop_address          51059 non-null object
# city                  50819 non-null object
# state                 50869 non-null object
# zip                   51014 non-null object
# prop_owner            51438 non-null object
# complaint_source      51344 non-null object
# reported_problem      50730 non-null object
# status                51438 non-null object
# council_district      50901 non-null object
# last_activity_date    51073 non-null object
# last_activity         51073 non-null object
# last_activity_code    51063 non-null object
# violations_noted      35606 non-null object
# mapped_loc            51061 non-null object
# dtypes: object(17)
# memory usage: 6.7+ MB

# %%
df4
# Out:
#         request_no   date_recv        prop_apn           prop_address  \
# 0       17-1156755  2017-05-04     05814005400         121  QUEENS LN
# 1       17-1165789  2017-08-24     08116056500       1007  11TH AVE N
# 2       17-1157131  2017-05-09     10703001600          715  ERMAC DR
# 3       17-1161502  2017-07-06     07116009000     903  BLUE RIDGE DR
# 4       17-1153921  2017-03-06     11813018100    3605B  MAYFLOWER PL
# 5       17-1153921  2017-03-06     11813018100    3605B  MAYFLOWER PL
# 6       17-1153921  2017-03-06     11813018100    3605B  MAYFLOWER PL
# 7       17-1153921  2017-03-06     11813018100    3605B  MAYFLOWER PL
# 8       17-1156955  2017-05-08     12001009000      1202  VULTEE BLVD
# 9       17-1156955  2017-05-08     12001009000      1202  VULTEE BLVD
# 10      17-1156955  2017-05-08     12001009000      1202  VULTEE BLVD
# 11      17-1156955  2017-05-08     12001009000      1202  VULTEE BLVD
# ...

# %%
df4.to_csv('violations_df4.csv')

# %%
type(new_codes)
new_codes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 16 columns):
# VIOLATION_ID      928 non-null object
# ORG_ID            789 non-null object
# VIOLATION_TYPE    788 non-null object
# VIOLATION_DESC    925 non-null object
# VIOLATION_TEXT    666 non-null object
# REMEDIAL_TEXT     345 non-null object
# TABLE_NAME        137 non-null datetime64[ns]
# EXPIRED_FLAG      651 non-null object
# DATE_EXPIRED      2 non-null object
# CREATED_BY        650 non-null float64
# DATE_CREATED      651 non-null object
# MODIFIED_BY       23 non-null object
# DATE_MODIFIED     22 non-null datetime64[ns]
# FEE_SETUP_ID      0 non-null float64
# Unnamed: 14       0 non-null float64
# CATEGORY          788 non-null object
# dtypes: datetime64[ns](2), float64(3), object(11)
# memory usage: 116.8+ KB

# %%
#merge1=pd.merge(new_codes, df4, how='right', left_on=['CATEGORY'], right_on=['v'])
#merge1.info()

# %%
vio_with_cats = df4.join(new_codes['CATEGORY'], how='left')

# %%
vio_with_cats.to_csv('output_join.csv')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104320 entries, 0 to 104319
# Data columns (total 17 columns):
# request_no            104320 non-null object
# date_recv             104320 non-null object
# prop_apn              103706 non-null object
# prop_address          103796 non-null object
# city                  103399 non-null object
# state                 103474 non-null object
# zip                   103731 non-null object
# prop_owner            104320 non-null object
# complaint_source      104078 non-null object
# reported_problem      102991 non-null object
# status                104320 non-null object
# council_district      103551 non-null object
# last_activity_date    103949 non-null object
# last_activity         103949 non-null object
# last_activity_code    103921 non-null object
# mapped_loc            103798 non-null object
# v                     88488 non-null object
# dtypes: object(17)
# memory usage: 13.5+ MB

# %%
cf=new_codes
new_category = pd.DataFrame([['Unknown', 'UNK']], columns=['VIOLATION_DESC', 'CATEGORY'])
cf = cf.append(new_category)

# %%
new_codes
# Out:
#                                           VIOLATION_ID            ORG_ID  \
# 0                                                    1                 1
# 1                                                    2                 1
# 2                                                    4                 1
# 3                                                    5                 1
# 4                                                    6                 1
# 5                                                    7                 1
# 6                                                    8                 1
# 7                                                    9                 1
# 8                                                   10                 1
# 9                                                   11                 1
# 10                                                  12                 1
# 11                                                  13                 1
# ...

# %%
codes=new_codes
nf=df4
s1 = codes['VIOLATION_DESC'].str.split(',', expand=True).stack().str.strip().reset_index(level=1, drop=True)
t = pd.concat([s1], axis=1, keys=['VIOLATION_DESC'])
cf = codes.drop(['VIOLATION_DESC'], axis=1).join(t).reset_index(drop=True)
nf['v'] = nf['v'].replace(np.NaN, 'Unknown')
new_category = pd.DataFrame([['Unknown', 'UNK']], columns=['VIOLATION_DESC', 'CATEGORY'])
cf = cf.append(new_category)

# finding 2 different encodings of hyphens in each
nf['v'] = nf['v'].str.replace(chr(65533), '-')
cf['VIOLATION_DESC'] = cf['VIOLATION_DESC'].str.replace(chr(226)+chr(128)+chr(147), '-')

# setting merging columns to lower case 
nf['v'] = nf['v'].str.lower()
cf['VIOLATION_DESC'] = cf['VIOLATION_DESC'].str.lower()

new_df = pd.merge(left=nf, right=cf, how='inner', left_on='v', right_on='VIOLATION_DESC')

# %%
codes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 16 columns):
# VIOLATION_ID      928 non-null object
# ORG_ID            789 non-null object
# VIOLATION_TYPE    788 non-null object
# VIOLATION_DESC    925 non-null object
# VIOLATION_TEXT    666 non-null object
# REMEDIAL_TEXT     345 non-null object
# TABLE_NAME        137 non-null datetime64[ns]
# EXPIRED_FLAG      651 non-null object
# DATE_EXPIRED      2 non-null object
# CREATED_BY        650 non-null float64
# DATE_CREATED      651 non-null object
# MODIFIED_BY       23 non-null object
# DATE_MODIFIED     22 non-null datetime64[ns]
# FEE_SETUP_ID      0 non-null float64
# Unnamed: 14       0 non-null float64
# CATEGORY          788 non-null object
# dtypes: datetime64[ns](2), float64(3), object(11)
# memory usage: 116.8+ KB

# %%
new_df
# Out:
#         request_no   date_recv        prop_apn                prop_address  \
# 0       17-1156755  2017-05-04     05814005400              121  QUEENS LN
# 1       17-1157131  2017-05-09     10703001600               715  ERMAC DR
# 2       17-1155963  2017-04-24     07301023500          3917  MOSS ROSE DR
# 3       17-1156643  2017-05-02  072090Y00200CO            1003D  SPAIN AVE
# 4       16-1141470  2016-06-15     07116043100          907  BLUE RIDGE DR
# 5       17-1160924  2017-06-27     08104019100             1835  3RD AVE N
# 6       17-1161209  2017-06-30     04415027500           1007  ELLISTON ST
# 7       17-1153795  2017-03-03     16216004000       5418  HICKORY PARK DR
# 8       17-1159515  2017-06-07     16208006200             36  TUSCULUM RD
# 9       17-1164425  2017-08-08  164100A04500CO          4216  SANDSTONE DR
# 10      17-1163877  2017-08-02  104114A00100CO         2001  CONVENT PL  1
# ...

# %%
s1 = codes['VIOLATION_DESC'].str.split(',', expand=True).stack().str.strip().reset_index(level=1, drop=True)

# %%
cf
# Out:
#     CATEGORY  CREATED_BY                DATE_CREATED  \
# 0       CAAZ         1.0  2014-07-09 08:03:52.640000
# 1       CAAH         1.0  2014-07-09 08:03:52.640000
# 2       CAAH         1.0  2014-07-09 08:03:52.640000
# 3       CAAB         1.0  2014-07-09 08:03:52.640000
# 4       CAAH         1.0  2014-07-09 08:03:52.640000
# 5       CAAH         1.0  2014-07-09 08:03:52.640000
# 6       CAAH         1.0  2014-07-09 08:03:52.640000
# 7        CAM         1.0  2014-07-09 08:03:52.640000
# 8       CAAZ         1.0  2014-07-09 08:03:52.640000
# 9       CAAH         1.0  2014-07-09 08:03:52.640000
# 10      CAAZ         1.0  2014-07-09 08:03:52.640000
# 11      CAAZ         1.0  2014-07-09 08:03:52.640000
# 12      CAAZ         1.0  2014-07-09 08:03:52.640000
# 13      CAAZ         1.0  2014-07-09 08:03:52.640000
# 14       DUM         NaN                         NaN
# 15       NaN         NaN                         NaN
# 16       CAM         1.0  2014-07-09 08:03:52.640000
# ...

# %%
new_df.shape
# Out:
# (98262, 33)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98262 entries, 0 to 98261
# Data columns (total 33 columns):
# request_no            98262 non-null object
# date_recv             98262 non-null object
# prop_apn              97657 non-null object
# prop_address          97750 non-null object
# city                  97343 non-null object
# state                 97418 non-null object
# zip                   97685 non-null object
# prop_owner            98262 non-null object
# complaint_source      98019 non-null object
# reported_problem      96894 non-null object
# status                98262 non-null object
# council_district      97512 non-null object
# last_activity_date    97890 non-null object
# last_activity         97890 non-null object
# last_activity_code    97868 non-null object
# mapped_loc            97752 non-null object
# v                     98262 non-null object
# CATEGORY              98262 non-null object
# CREATED_BY            79679 non-null float64
# ...

# %%
q=new_df[['mapped_loc','v','CATEGORY','REMEDIAL_TEXT','VIOLATION_DESC','VIOLATION_TYPE']]

# %%
q
# Out:
#                                               mapped_loc  \
# 0      121 QUEENS LN\nNASHVILLE, TN 37218\n(36.213718...
# 1      715 ERMAC DR\nNASHVILLE, TN 37214\n(36.146283,...
# 2      3917 MOSS ROSE DR\nNASHVILLE, TN 37216\n(36.21...
# 3      1003D SPAIN AVE\nNASHVILLE, TN 37216\n(36.2010...
# 4      907 BLUE RIDGE DR\nNASHVILLE, TN 37207\n(36.19...
# 5      1835 3RD AVE N\nNASHVILLE, TN 37208\n(36.18704...
# 6      1007 ELLISTON ST\nOLD HICKORY, TN 37138\n(36.2...
# 7      5418 HICKORY PARK DR\nANTIOCH, TN 37013\n(36.0...
# 8      36 TUSCULUM RD\nANTIOCH, TN 37013\n(36.05302, ...
# 9      4216 SANDSTONE DR\nANTIOCH, TN 37013\n(36.0474...
# 10     2001 CONVENT PL 1\nNASHVILLE, TN 37212\n(36.13...
# 11     699 MERCER DR\nHERMITAGE, TN 37076\n(36.198527...
# 12     3071 ELM HILL PIKE\nNASHVILLE, TN 37214\n(36.1...
# 13     306 CHAMBERLIN ST\nNASHVILLE, TN 37209\n(36.14...
# 14     2019 9TH AVE N\nNASHVILLE, TN 37208\n(36.18615...
# ...
